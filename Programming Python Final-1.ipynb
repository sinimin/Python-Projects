# %% [markdown]
# # Quality and Cost of Healthcare
# Please submit this .ipynb file and compiled output (as .html or .pdf)
#
#
# *Scenario:*
#
# Welcome to Care4All PCPs, the largest Primary Care Network in the state of California! We are glad to have someone with your analytical prowess on board. We are interested in ensuring that our patients get the highest quality care at the fairest price. To that end, we hired a consultant to perform an analysis of hospitals in California to help us understand
# 1) Which hospitals are the highest quality?
# 2) Which hospitals charge the most/least?
#
# Based on our request, the consultant provided data and code for each of those questions. While this was helpful, we want to rewrite the code in a different language and explain it in detail (no comments or explanations were provided). Then, we would like to extend this work to learn about the relationship between health quality and cost for our patients. Therefore, we have laid out 3 tasks.
#
# **Your Tasks:**
#
# Task 1: Describe hospital quality ratings in California
#
#       Using code written in R, 1a) Explain the code then 1b) Translate that code into Python, improving it as neccessary to best answer the question
#
# Task 2: Describe procedure prices at hospitals in California
#
#       Using code written in Python, 2a) Explain the code, then 2b) Translate that code into R, improving it as necessary to best answer the question
#
# Task 3: Combine Data and Create Visualization
#
#        Use the data from the first two tasks to determine the relationship between price and quality.
#
# *
#
# *Hints and Advice*
# * The most important thing is that you understand the function of the code and can write code in another language that gives the equivalent output - there is no single correct solution to these tasks
# * If you are unsure about what a particular block of code (out of a larger chunk) does, run that bit in isolation and note the changes to the output.
# * Don't forget to check the Code Companions and live class slides for explanations of functions or equivalencies between the two languages.

# %% [markdown]
# # Hospital Quality Overall
#
# ## Task 1: Summarize *quality ratings* in the state of California
# ***Motivating Question*** : **Which hospitals are the highest quality?**
#
#
# For this task, you are given a .csv from *data.medicare.gov/data/hospital-compare* to help answer the question. This dataset contains identifying information for the hospital (Provider ID, Hospital Name, Phone Number, etc.) as well as Medicare-determined quality metrics (Overall rating, national comparison, safety of care, etc.).
#
#
# ### 1a) Explain the code
# Explain in as much detail as possible what the code is doing and how it arrives at the final output table. How does this address the task of describing quality ratings of hospitals in California?

# %% [raw]
# {r 1a Code Explanation}
# # Get the unique hospital names
# hosp_names = hosp_info %>%
#   filter(`Hospital Type` == "Acute Care Hospitals") %>%
#   filter(State == "CA") %>%
#   pull(`Hospital Name`)
#
# # Filter based on those hospital names
# hosp_info_CA =
# hosp_info %>%
#   rename(Hospital = `Hospital Name`,
#          Provider_ID = `Provider ID`,
#          Safety = `Safety of care national comparison`,
#          Effectiveness = `Effectiveness of care national comparison`
#          ) %>%
#   filter(Hospital %in% hosp_names, State == "CA") %>%
#   mutate(Overall_Rating = as.numeric(`Hospital overall rating`)) %>%
#   drop_na(Overall_Rating)
#
# hosp_info_CA %>%
#   arrange(desc(Overall_Rating), Hospital) %>%
#   head(7)
#
# hosp_info_CA %>%
#   group_by(Overall_Rating, Safety) %>%
#   count()
#
# write_csv(hosp_info_CA, 'hosp_info_CA.csv')

# %% [markdown]
# ### 1b) Translate the code into Python and provide insights
# Translate that code from R to Python, improving it if neccessary to best address the question: **Which hospitals are the highest quality?**.
#
# Provide your insights from the output of the code.

# %%
import pandas as pd
import numpy as np
# Get the unique hospital names
hosp_info = pd.read_csv('HospInfo.csv')
hosp_names = hosp_info[
    (hosp_info['Hospital Type'] == 'Acute Care Hospitals') &
    (hosp_info['State'] == 'CA')]
hosp_names['Hospital Name'].tolist()
# Out:
# ['SAN GORGONIO MEMORIAL HOSPITAL',
#  'WHITE MEMORIAL MEDICAL CENTER',
#  'KAISER FOUNDATION HOSPITAL - LOS ANGELES',
#  'COMMUNITY HOSPITAL OF THE MONTEREY PENINSULA',
#  'HOAG MEMORIAL HOSPITAL PRESBYTERIAN',
#  'MERCY MEDICAL CENTER REDDING',
#  'SUTTER ROSEVILLE MEDICAL CENTER',
#  'EDEN MEDICAL CENTER',
#  'SONOMA DEVELOPMENTAL CENTER',
#  'MISSION HOSPITAL REGIONAL MED CENTER',
#  'MENIFEE VALLEY MEDICAL CENTER',
#  'LAC/RANCHO LOS AMIGOS NATIONAL REHABILITATION  CTR',
#  'ST JOHNS REGIONAL MEDICAL CENTER',
#  'METHODIST HOSPITAL OF SOUTHERN CA',
#  'RIVERSIDE COMMUNITY HOSPITAL',
#  'JOHN MUIR MEDICAL CENTER - WALNUT CREEK CAMPUS',
#  'ARROWHEAD REGIONAL MEDICAL CENTER',
#  'SAN RAMON REGIONAL MEDICAL CTR',
#  'KAISER FOUNDATION HOSPITAL - FRESNO',
#  'ST JOSEPH HOSPITAL',
#  'SANTA MONICA - UCLA MED CTR & ORTHOPAEDIC HOSPITAL',
#  'MIRACLE MILE MEDICAL CENTER',
#  'FEATHER RIVER HOSPITAL',
#  'MARINA DEL REY HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - WALNUT CREEK',
#  'PETALUMA VALLEY HOSPITAL',
#  'METHODIST HOSPITAL OF SACRAMENTO',
#  'SAINT FRANCIS MEMORIAL HOSPITAL',
#  'MERCY SAN JUAN MEDICAL CENTER',
#  'JOHN MUIR MEDICAL CENTER - CONCORD CAMPUS',
#  'HEMET VALLEY MEDICAL CENTER',
#  'TULARE REGIONAL MEDICAL CENTER',
#  'RIDEOUT MEMORIAL HOSPITAL',
#  'ANAHEIM GLOBAL MEDICAL CENTER',
#  'ALTA BATES SUMMIT MEDICAL CENTER',
#  'UCSF MEDICAL CENTER',
#  'SIERRA VISTA REGIONAL MEDICAL CENTER',
#  'SAINT AGNES MEDICAL CENTER',
#  'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD',
#  'COMMUNITY HOSPITAL OF SAN BERNARDINO',
#  'SUTTER SANTA ROSA REGIONAL HOSPITAL',
#  'COMMUNITY MEMORIAL HOSPITAL SAN BUENAVENTURA',
#  'DESERT VALLEY HOSPITAL',
#  'VICTOR VALLEY GLOBAL MEDICAL CENTER',
#  'MONTCLAIR HOSPITAL MEDICAL CENTER',
#  'SHASTA REGIONAL MEDICAL CENTER',
#  'SANTA ROSA MEMORIAL HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - VACAVILLE',
#  'MERCY HOSPITAL',
#  'COMMUNITY HOSPITAL OF LONG BEACH',
#  'COAST PLAZA HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL-SANTA ROSA',
#  'GEORGE L MEE MEMORIAL HOSPITAL',
#  'NATIVIDAD MEDICAL CENTER',
#  'EISENHOWER MEDICAL CENTER',
#  'ORANGE COUNTY GLOBAL MEDICAL CENTER',
#  'SOUTH COAST GLOBAL MEDICAL CENTER',
#  'WEST COVINA MEDICAL CENTER, INC',
#  'ADVENTIST MEDICAL CENTER - REEDLEY',
#  'LOMPOC VALLEY MEDICAL CENTER',
#  'CHINO VALLEY MEDICAL CENTER',
#  'TRI-CITY MEDICAL CENTER',
#  'FOOTHILL REGIONAL MEDICAL CENTER',
#  'UKIAH VALLEY MEDICAL CENTER',
#  'CALIFORNIA PACIFIC MEDICAL CTR-DAVIES CAMPUS HOSP',
#  'KAISER FOUNDATION HOSPITAL - SAN LEANDRO',
#  'ALHAMBRA HOSPITAL MEDICAL CENTER',
#  'SCRIPPS MERCY HOSPITAL',
#  'REDLANDS COMMUNITY HOSPITAL',
#  'SIMI VALLEY HOSPITAL & HEALTH CARE SERVICES',
#  'EAST LOS ANGELES DOCTORS HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - SAN DIEGO',
#  'SAN FRANCISCO GENERAL HOSPITAL',
#  "PATIENTS' HOSPITAL OF REDDING",
#  'SILVER LAKE MEDICAL CENTER',
#  'SHARP CHULA VISTA MEDICAL CENTER',
#  'SUTTER DELTA MEDICAL CENTER',
#  'ST BERNARDINE MEDICAL CENTER',
#  'LOMA LINDA UNIVERSITY MEDICAL CENTER-MURRIETA',
#  'PRESBYTERIAN INTERCOMMUNITY HOSPITAL',
#  'REGIONAL MEDICAL CENTER OF SAN JOSE',
#  'SUTTER AMADOR HOSPITAL',
#  'ST ROSE HOSPITAL',
#  'LODI MEMORIAL HOSPITAL',
#  'ORANGE COAST MEMORIAL MEDICAL CENTER',
#  'SALINAS VALLEY MEMORIAL HOSPITAL',
#  'OAK VALLEY HOSPITAL DISTRICT',
#  'PARADISE VALLEY HOSPITAL',
#  'USC VERDUGO HILLS HOSPITAL',
#  'CASA COLINA HOSPITAL',
#  'ENLOE MEDICAL CENTER',
#  'CALIFORNIA PACIFIC MEDICAL CTR-PACIFIC CAMPUS HOSP',
#  'PROVIDENCE TARZANA MEDICAL CENTER',
#  'MEMORIAL HOSPITAL OF GARDENA',
#  'EL CAMINO HOSPITAL',
#  'ST MARY MEDICAL CENTER',
#  'STANFORD HEALTH CARE',
#  'LA PALMA INTERCOMMUNITY HOSPITAL',
#  'FOUNTAIN VALLEY REGIONAL HOSPITAL & MEDICAL CENTER',
#  'COLLEGE MEDICAL CENTER',
#  'PLACENTIA LINDA HOSPITAL',
#  'MAD RIVER COMMUNITY HOSPITAL',
#  'MARIN GENERAL HOSPITAL',
#  'MADERA COMMUNITY HOSPITAL',
#  'SUTTER DAVIS HOSPITAL',
#  'PALMDALE REGIONAL MEDICAL CENTER',
#  'SONORA REGIONAL MEDICAL CENTER',
#  'MISSION COMMUNITY HOSPITAL',
#  'HOLLYWOOD PRESBYTERIAN MEDICAL CENTER',
#  'SCRIPPS GREEN HOSPITAL',
#  'CALIFORNIA HOSPITAL MEDICAL CENTER LA',
#  'ST ELIZABETH COMMUNITY HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - WEST LA',
#  'KAISER FOUNDATION HOSPITAL - ROSEVILLE',
#  'COLLEGE HOSPITAL COSTA MESA',
#  'HUNTINGTON MEMORIAL HOSPITAL',
#  "CALIFORNIA PACIFIC MEDICAL CTR - ST. LUKE'S CAMPUS",
#  'NORTHBAY MEDICAL CENTER',
#  'LAKEWOOD REGIONAL MEDICAL CENTER',
#  'MERCY HOSPITAL OF FOLSOM',
#  'KECK HOSPITAL OF USC',
#  'DOCTORS MEDICAL CENTER',
#  'SAN GABRIEL VALLEY MEDICAL CENTER',
#  'SUTTER MEDICAL CENTER, SACRAMENTO',
#  'FRENCH HOSPITAL MEDICAL CENTER',
#  'GLENDORA COMMUNITY HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - FREMONT',
#  'STANFORD HEALTH CARE - VALLEYCARE',
#  'UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER',
#  'UC SAN DIEGO HEALTH HILLCREST - HILLCREST MED CTR',
#  'KAISER FOUNDATION HOSPITAL-SANTA CLARA',
#  'LONG BEACH MEMORIAL MEDICAL CENTER',
#  'SHARP CORONADO HOSPITAL AND HLTHCR CTR',
#  'KAISER FOUNDATION HOSPITAL',
#  "ST JOSEPH'S MEDICAL CENTER OF STOCKTON",
#  'SCRIPPS MEMORIAL HOSPITAL - ENCINITAS',
#  'GREATER EL MONTE COMMUNITY HOSPITAL',
#  'WHITTIER HOSPITAL MEDICAL CENTER',
#  'ST JOSEPH HOSPITAL',
#  'PALOMAR HEALTH DOWNTOWN CAMPUS',
#  'SOUTHWEST HEALTHCARE SYSTEM',
#  'SAN JOAQUIN GENERAL HOSPITAL',
#  'LOS ALAMITOS MEDICAL CENTER',
#  'ALAMEDA HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL-SAN JOSE',
#  'POMERADO HOSPITAL',
#  'SIERRA VIEW MEDICAL CENTER',
#  'HIGHLAND HOSPITAL',
#  'MERCY MEDICAL CENTER',
#  'MILLS-PENINSULA MEDICAL CENTER',
#  'LAC+USC MEDICAL CENTER',
#  'GARDEN GROVE HOSPITAL & MEDICAL CENTER',
#  'DELANO REGIONAL MEDICAL CENTER',
#  'WEST HILLS HOSPITAL & MEDICAL CENTER',
#  'HAZEL HAWKINS MEMORIAL HOSPITAL',
#  'MONTEREY PARK HOSPITAL',
#  'TEMECULA VALLEY HOSPITAL',
#  'PROVIDENCE LITTLE COMPANY OF MARY MED CTR TORRANCE',
#  'SUTTER COAST HOSPITAL',
#  'RONALD REAGAN U C L A MEDICAL CENTER',
#  'GROSSMONT HOSPITAL',
#  'JOHN F KENNEDY MEMORIAL HOSPITAL',
#  'SAN DIMAS COMMUNITY HOSPITAL',
#  'DESERT REGIONAL MEDICAL CENTER',
#  'GOOD SAMARITAN HOSPITAL',
#  'SIERRA NEVADA MEMORIAL HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO',
#  'SAINT LOUISE REGIONAL HOSPITAL',
#  "LOMA LINDA UNIVERSITY CHILDREN'S HOSPITAL",
#  'GARDENS REGIONAL HOSPITAL AND MEDICAL CENTER',
#  'NORTHRIDGE HOSPITAL MEDICAL CENTER',
#  'COMMUNITY HOSPITAL OF HUNTINGTON PARK',
#  'TORRANCE MEMORIAL MEDICAL CENTER',
#  'FRESNO SURGICAL HOSPITAL',
#  'BARTON MEMORIAL HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - SAN FRANCISCO',
#  'PIONEERS MEMORIAL HEALTHCARE DISTRICT',
#  'ANTELOPE VALLEY HOSPITAL',
#  'MARSHALL MEDICAL CENTER',
#  'PARKVIEW COMMUNITY HOSPITAL MEDICAL CENTER',
#  'KERN MEDICAL CENTER',
#  'SHERMAN OAKS HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - REDWOOD CITY',
#  'MEMORIAL MEDICAL CENTER',
#  'MENLO PARK SURGICAL HOSPITAL',
#  'BAKERSFIELD HEART HOSPITAL',
#  'CITRUS VALLEY MEDICAL CENTER-IC CAMPUS',
#  'SADDLEBACK MEMORIAL MEDICAL CENTER',
#  'CEDARS-SINAI MEDICAL CENTER',
#  'PROVIDENCE SAINT JOSEPH MEDICAL CTR',
#  'LOS ANGELES COMMUNITY HOSPITAL',
#  'FOOTHILL PRESBYTERIAN HOSPITAL',
#  'AHMC ANAHEIM REGIONAL MEDICAL CENTER',
#  'KAISER FOUNDATION HOSPITAL - OAKLAND/RICHMOND',
#  'GLENDALE MEM HOSPITAL & HLTH CENTER',
#  'BARSTOW COMMUNITY HOSPITAL',
#  'GOOD SAMARITAN HOSPITAL',
#  'LAGUNA HONDA HOSPITAL & REHABILITATION CENTER',
#  'ST HELENA HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL AND REHAB CENTER',
#  'CONTRA COSTA REGIONAL MEDICAL CENTER',
#  'CORONA REGIONAL MEDICAL CENTER',
#  'MERCY GENERAL HOSPITAL',
#  'ENCINO HOSPITAL MEDICAL CENTER',
#  'SONOMA WEST MEDICAL CENTER',
#  'MARIAN REGIONAL MEDICAL CENTER',
#  'MOTION PICTURE & TELEVISION HOSPITAL',
#  'GOOD SAMARITAN HOSPITAL',
#  'ALVARADO HOSPITAL MEDICAL CENTER',
#  "PROVIDENCE SAINT JOHN'S HEALTH CENTER",
#  'KAISER FOUNDATION HOSPITAL FONTANA',
#  'SAN LEANDRO HOSPITAL',
#  'PACIFIC ALLIANCE MEDICAL CENTER',
#  'SCRIPPS MEMORIAL HOSPITAL LA JOLLA',
#  'KAISER FOUNDATION HOSPITAL, RIVERSIDE',
#  'GARFIELD MEDICAL CENTER',
#  'KAWEAH DELTA MEDICAL CENTER',
#  'SHARP MEMORIAL HOSPITAL',
#  'LOMA LINDA UNIVERSITY MEDICAL CENTER',
#  'HUNTINGTON BEACH HOSPITAL',
#  'PACIFICA HOSPITAL OF THE VALLEY',
#  'OROVILLE HOSPITAL',
#  'SANTA CLARA VALLEY MEDICAL CENTER',
#  'PALO VERDE HOSPITAL',
#  'COMMUNITY REGIONAL MEDICAL CENTER',
#  'ST JOHNS PLEASANT VALLEY HOSPITAL',
#  'EL CENTRO REGIONAL MEDICAL CENTER',
#  'SANTA BARBARA COTTAGE HOSPITAL',
#  'ST MARY MEDICAL CENTER',
#  'KAISER FOUNDATION HOSPITAL - ORANGE COUNTY - ANAHE',
#  'CHAPMAN GLOBAL MEDICAL CENTER',
#  'KAISER FOUNDATION HOSPITAL-MORENO VALLEY',
#  'KAISER FOUNDATION HOSPITAL - SACRAMENTO',
#  'ADVENTIST MEDICAL CENTER',
#  'GOLETA VALLEY COTTAGE HOSPITAL',
#  'SAINT FRANCIS MEDICAL CENTER',
#  'KAISER FOUNDATION HOSP SO SACRAMENTO',
#  'KAISER FOUNDATION HOSPITAL - SOUTH BAY',
#  'WOODLAND MEMORIAL HOSPITAL',
#  'PORTERVILLE DEVELOPMENTAL CENTER',
#  'SUTTER AUBURN FAITH HOSPITAL',
#  'DOMINICAN HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - BALDWIN PARK',
#  'ST JUDE MEDICAL CENTER',
#  'SAINT VINCENT MEDICAL CENTER',
#  'DOCTORS HOSPITAL OF MANTECA',
#  'MEMORIAL HOSPITAL LOS BANOS',
#  'STANISLAUS SURGICAL HOSPITAL',
#  'HOAG ORTHOPEDIC INSTITUTE',
#  'UNIVERSITY OF CALIFORNIA IRVINE MED CENTER',
#  'QUEEN OF THE VALLEY MEDICAL CENTER',
#  'SUTTER TRACY COMMUNITY HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - PANORAMA CITY',
#  'WASHINGTON HOSPITAL',
#  "O'CONNOR HOSPITAL",
#  'CLOVIS COMMUNITY MEDICAL CENTER',
#  'TWIN CITIES COMMUNITY HOSPITAL',
#  'HENRY MAYO NEWHALL  HOSPITAL',
#  'EMANUEL MEDICAL CENTER',
#  'PROVIDENCE HOLY CROSS MEDICAL CENTER',
#  'PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO',
#  'KAISER FOUNDATION HOSPITAL - DOWNEY',
#  'DAMERON HOSPITAL',
#  'LOS ROBLES HOSPITAL & MEDICAL CENTER',
#  'PIH HOSPITAL - DOWNEY',
#  'SETON MEDICAL CENTER',
#  'GLENDALE ADVENTIST MEDICAL CENTER',
#  'BAKERSFIELD MEMORIAL HOSPITAL',
#  'VENTURA COUNTY MEDICAL CENTER',
#  'ALTA BATES SUMMIT MEDICAL CENTER - ALTA BATES CAMP',
#  'SONOMA VALLEY HOSPITAL',
#  'SUTTER SOLANO MEDICAL CENTER',
#  'SAN ANTONIO REGIONAL HOSPITAL',
#  'LAC/OLIVE VIEW-UCLA MEDICAL CENTER',
#  'LAC/HARBOR-UCLA MED CENTER',
#  'SEQUOIA HOSPITAL',
#  'FAIRVIEW DEVELOPMENTAL CENTER',
#  'SAN MATEO MEDICAL CENTER',
#  'CENTINELA HOSPITAL MEDICAL CENTER',
#  'KAISER FOUNDATION HOSPITAL MANTECA',
#  'KAISER FOUNDATION HOSPITAL - WOODLAND HILLS',
#  "ST MARY'S MEDICAL CENTER",
#  'WATSONVILLE COMMUNITY HOSPITAL',
#  'SAN JOAQUIN COMMUNITY HOSPITAL',
#  'SUTTER SURGICAL HOSPITAL - NORTH VALLEY',
#  'VALLEY PRESBYTERIAN HOSPITAL',
#  'COALINGA REGIONAL MEDICAL CENTER',
#  'HI-DESERT MEDICAL CENTER',
#  'NOVATO COMMUNITY HOSPITAL',
#  'CHINESE HOSPITAL',
#  'KAISER FOUNDATION HOSPITAL - ANTIOCH',
#  'RIVERSIDE UNIVERSITY HEALTH SYSTEM-MEDICAL CENTER',
#  'MARTIN LUTHER KING, JR. COMMUNITY HOSPITAL',
#  'BEVERLY HOSPITAL',
#  'WEST ANAHEIM MEDICAL CENTER',
#  'SUTTER MATERNITY & SURGERY CENTER OF SANTA CRUZ',
#  'POMONA VALLEY HOSPITAL MEDICAL CENTER',
#  'OLYMPIA MEDICAL CENTER']

# %%
hosp_info_CA = (hosp_info.rename(columns={
    'Hospital Name': 'Hospital',
    'Provider ID': 'Provider_ID',
    'Safety of care national comparison': 'Safety',
    'Effectiveness of care national comparison': 'Effectiveness',
})
                        .loc[(hosp_info['Hospital Name'].isin(hosp_names['Hospital Name'])) & (hosp_info['State'] == 'CA')])
hosp_info_CA['Overall_Rating'] = pd.to_numeric(hosp_info['Hospital overall rating'], errors = 'coerce')   
hosp_info_CA.dropna(subset=['Overall_Rating'], inplace=True)             

hosp_info_CA
# Out:
#       Provider_ID                                           Hospital  \
# 24          50054                     SAN GORGONIO MEMORIAL HOSPITAL
# 25          50103                      WHITE MEMORIAL MEDICAL CENTER
# 26          50138           KAISER FOUNDATION HOSPITAL - LOS ANGELES
# 27          50145       COMMUNITY HOSPITAL OF THE MONTEREY PENINSULA
# 28          50224                HOAG MEMORIAL HOSPITAL PRESBYTERIAN
# ...           ...                                                ...
# 1324        50292  RIVERSIDE UNIVERSITY HEALTH SYSTEM-MEDICAL CENTER
# 1327        50350                                   BEVERLY HOSPITAL
# 1339        50426                        WEST ANAHEIM MEDICAL CENTER
# 1346        50231              POMONA VALLEY HOSPITAL MEDICAL CENTER
# 1347        50742                             OLYMPIA MEDICAL CENTER
#
#                                 Address           City State  ZIP Code  \
# 24    600 NORTH HIGHLAND SPRINGS AVENUE        BANNING    CA     92220
# 25                  1720 E CESAR AVENUE    LOS ANGELES    CA     90033
# 26                     4867 SUNSET BLVD    LOS ANGELES    CA     90027
# 27             23625 W R HOLMAN HIGHWAY       MONTEREY    CA     93940
# 28                       ONE HOAG DRIVE  NEWPORT BEACH    CA     92663
# ...                                 ...            ...   ...       ...
# 1324                26520 CACTUS AVENUE  MORENO VALLEY    CA     92555
# 1327                 309 W BEVERLY BLVD     MONTEBELLO    CA     90640
# 1339               3033 W ORANGE AVENUE        ANAHEIM    CA     92804
# 1346                   1798 N GAREY AVE         POMONA    CA     91767
# 1347        5900 WEST OLYMPIC BOULEVARD    LOS ANGELES    CA     90036
#
#       County Name  Phone Number         Hospital Type  \
# 24      RIVERSIDE    9518451121  Acute Care Hospitals
# 25    LOS ANGELES    3232685000  Acute Care Hospitals
# 26    LOS ANGELES    3237834011  Acute Care Hospitals
# 27       MONTEREY    8316245311  Acute Care Hospitals
# 28         ORANGE    9497644624  Acute Care Hospitals
# ...           ...           ...                   ...
# 1324    RIVERSIDE    9514864000  Acute Care Hospitals
# 1327  LOS ANGELES    3237261222  Acute Care Hospitals
# 1339       ORANGE    7148273000  Acute Care Hospitals
# 1346  LOS ANGELES    9098659500  Acute Care Hospitals
# 1347  LOS ANGELES    3106575900  Acute Care Hospitals
#
#                                Hospital Ownership  ...  \
# 24    Government - Hospital District or Authority  ...
# 25                  Voluntary non-profit - Church  ...
# 26                   Voluntary non-profit - Other  ...
# 27                 Voluntary non-profit - Private  ...
# 28                 Voluntary non-profit - Private  ...
# ...                                           ...  ...
# 1324                           Government - Local  ...
# 1327               Voluntary non-profit - Private  ...
# 1339                                  Proprietary  ...
# 1346               Voluntary non-profit - Private  ...
# 1347                                  Proprietary  ...
#
#       Patient experience national comparison  \
# 24                Below the national average
# 25                Below the national average
# 26                Below the national average
# 27                Above the national average
# 28                Above the national average
# ...                                      ...
# 1324              Below the national average
# 1327              Below the national average
# 1339              Below the national average
# 1346            Same as the national average
# 1347              Below the national average
#
#      Patient experience national comparison footnote  \
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# ...                                              ...
# 1324                                             NaN
# 1327                                             NaN
# 1339                                             NaN
# 1346                                             NaN
# 1347                                             NaN
#
#                      Effectiveness  \
# 24    Same as the national average
# 25    Same as the national average
# 26    Same as the national average
# 27    Same as the national average
# 28    Same as the national average
# ...                            ...
# 1324  Same as the national average
# 1327  Same as the national average
# 1339  Same as the national average
# 1346  Same as the national average
# 1347  Same as the national average
#
#      Effectiveness of care national comparison footnote  \
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# ...                                                 ...
# 1324                                                NaN
# 1327                                                NaN
# 1339                                                NaN
# 1346                                                NaN
# 1347                                                NaN
#
#      Timeliness of care national comparison  \
# 24               Below the national average
# 25               Below the national average
# 26                            Not Available
# 27             Same as the national average
# 28             Same as the national average
# ...                                     ...
# 1324             Below the national average
# 1327             Below the national average
# 1339             Below the national average
# 1346             Below the national average
# 1347           Same as the national average
#
#         Timeliness of care national comparison footnote  \
# 24                                                  NaN
# 25                                                  NaN
# 26    Results are not available for this reporting p...
# 27                                                  NaN
# 28                                                  NaN
# ...                                                 ...
# 1324                                                NaN
# 1327                                                NaN
# 1339                                                NaN
# 1346                                                NaN
# 1347                                                NaN
#
#      Efficient use of medical imaging national comparison  \
# 24                                        Not Available
# 25                         Same as the national average
# 26                                        Not Available
# 27                           Above the national average
# 28                           Below the national average
# ...                                                 ...
# 1324                                      Not Available
# 1327                       Same as the national average
# 1339                       Same as the national average
# 1346                       Same as the national average
# 1347                                      Not Available
#
#      Efficient use of medical imaging national comparison footnote  \
# 24    Results are not available for this reporting p...
# 25                                                  NaN
# 26    Results are not available for this reporting p...
# 27                                                  NaN
# 28                                                  NaN
# ...                                                 ...
# 1324  Results are not available for this reporting p...
# 1327                                                NaN
# 1339                                                NaN
# 1346                                                NaN
# 1347  Results are not available for this reporting p...
#
#                                                Location Overall_Rating
# 24     600 NORTH HIGHLAND SPRINGS AVENUE\nBANNING, CA\n            2.0
# 25               1720 E CESAR AVENUE\nLOS ANGELES, CA\n            3.0
# 26                  4867 SUNSET BLVD\nLOS ANGELES, CA\n            3.0
# 27             23625 W R HOLMAN HIGHWAY\nMONTEREY, CA\n            5.0
# 28                  ONE HOAG DRIVE\nNEWPORT BEACH, CA\n            4.0
# ...                                                 ...            ...
# 1324  26520 CACTUS AVENUE\nMORENO VALLEY, CA\n(33.91...            3.0
# 1327  309 W BEVERLY BLVD\nMONTEBELLO, CA\n(34.016032...            3.0
# 1339  3033 W ORANGE AVENUE\nANAHEIM, CA\n(33.824735,...            3.0
# 1346  1798 N GAREY AVE\nPOMONA, CA\n(34.077639, -117...            3.0
# 1347  5900 WEST OLYMPIC BOULEVARD\nLOS ANGELES, CA\n...            2.0
#
# [276 rows x 30 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Address, City, State, ZIP Code, County Name, Phone Number, Hospital Type, Hospital Ownership, Emergency Services, Meets criteria for meaningful use of EHRs, Hospital overall rating, Hospital overall rating footnote, Mortality national comparison, Mortality national comparison footnote, Safety of care national comparison, Safety of care national comparison footnote, Readmission national comparison, Readmission national comparison footnote, Patient experience national comparison, Patient experience national comparison footnote, Effectiveness of care national comparison, Effectiveness of care national comparison footnote, Timeliness of care national comparison, Timeliness of care national comparison footnote, Efficient use of medical imaging national comparison, Efficient use of medical imaging national comparison footnote, Location, Overall_Rating]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ## Task 2: Summarize *hospital costs* in the state of California
# ***Motivating Question*** : **Which hospitals charge the most/least?**
#
# For this task, you are given a .csv from *https://data.cms.gov/Medicare-Inpatient/Inpatient-Prospective-Payment-System-IPPS-Provider/97k6-zzx3* to help investigate hospital costs in California. The dataset contains identifying information for the hospital (Provider ID, Hospital Name, Address, Zip Code), the diagnosis-related group (DRG), and associated costs (Average Total Payments, Average Medicare Payments)
#
# *Average Total Payments*:
# The average of Medicare payments to the provider for the DRG including the DRG amount, teaching,  disproportionate share, capital, and outlier payments for all cases. Also included are co-payment and deductible amounts that the patient is responsible for.

# %% [markdown]
# ### Task 2a) Explain the code
# Explain in as much detail as possible what the code is doing and how it arrives at the final output table that is written to a CSV. How does this address the task of describing the cost of care at hospitals in California?
#
# *Add comments in the code and a several sentence summary to complete this task.*

# %%
import pandas as pd
import numpy as np

# %%
costs = pd.read_csv("Inpatient_Prospective_Payment_System__IPPS__Provider_Summary_for_the_Top_100_Diagnosis-Related_Groups__DRG__-_FY2011.csv")
#This line of code uses the pandas package, which is designated by the pd. The function 'pd.read_csv' is a function designed to import csv files into python.

costs = costs.rename(columns = {'DRG Definition': 'DRG',
                               ' Average Total Payments ': 'Total_Cost', # Note spaces around ' Average Total Payments '
                               ' Total Discharges ': 'Count_Discharges'}) # Note spaces around ' Total Discharges '
#The rename method is used here. This method is used to renmame columns wtihin the 'costs' dataframe. The change of names for the columns listed is then 
#saved to the orignal dataframe 'costs'. 'DRG Definition' is renamed to 'DRG' and this is true for the other 2 column name changes.

costs[['DRG_Code', 'DRG_Description']] = costs['DRG'].str.split(' - ', expand = True) # Note spaces around ' - '
costs = costs.drop(['DRG'], axis = 1)
#The line of code, 'costs[['DRG_Code', 'DRG_Description']]' function is to create two new columns: 'DRG_Code' and 'DRG_Description'. The .str.split 
#method is used to split the code. The code within the .str.split(), or '(' - ', expand = True)', functions to split the string within the 'DRG' column.
#It does this by looking for the specific string ' - ' and seperating the string before the hyphen and after the hyphen. The 'expand = true' portion
#insures that the strings after the hyphen are place in a new column.

costs['Avg_DRG_Cost'] = costs.groupby('DRG_Code')['Total_Cost'].transform(np.mean)
costs['Cost_Diff'] = costs['Total_Cost'] - costs['Avg_DRG_Cost']
#The first portion of the code, 'costs['Avg_DRG_Cost'] = ', creates a new column within the cost data frame. The column will be filled with what follows 
#the equal sign. This code uses the .groupby() function to group the columns 'DRG_Code' and 'Total_Cost'. Then the .transform method applies the .mean, 
#function to calculate the mean value of 'Total_Cost' for each 'DRG_Code' value in the data frame.

# %%
top_drgs = (costs
            .groupby('DRG_Code')['Count_Discharges']
            .sum()
            .sort_values(ascending = False)
           )
#Top_drgs is a new data frame that is set to equal a specific subset of the costs data frame. The .groupby funtion is used to
#group the data frame by the unique values in the 'DRG_Code' column. Then, the column 'Count_Discharges' is selected to perform 
#a sum calculation for the values in this column. The code is then sorted in descending order, where the .sort_values method 
#sorts the sum values in descending order, or 'ascending = False'.

top_drgs.index[0]
#This line of code gives us the first value of the index of top_drgs. This value would correspond to the 'DRG_Code' column and give us the
#highest sum within the 'Count_Discharges' column.
# Out:
# '470'

# %%
(costs
 .query("DRG_Code == '470' and `Provider State` == 'CA'")
 .to_csv("Hip_Replacement_Costs_by_Hosp.csv", index = False)
)
#This line of code uses the .query() method to filter rows where 'DRG_Code' column has a value of'470'. Then the filtered data 
#frame is saved to a CSV file and named 'Hip_Replacement_Costs_by_Hosp.csv'. 'index = False' ensures that the data frame's index
#won't be saved as a seperate column.
# Out:
#         Provider Id                            Provider Name  \
# 111406        50002                         ST ROSE HOSPITAL
# 111407        50006                       ST JOSEPH HOSPITAL
# 111408        50007                 PENINSULA MEDICAL CENTER
# 111409        50009       QUEEN OF THE VALLEY MEDICAL CENTER
# 111410        50013                       ST HELENA HOSPITAL
# ...             ...                                      ...
# 111637        50760     KAISER FOUNDATION HOSPITAL - ANTIOCH
# 111638        50761        PROVIDENCE TARZANA MEDICAL CENTER
# 111639        50764           SHASTA REGIONAL MEDICAL CENTER
# 111640        50766  SUTTER SURGICAL HOSPITAL - NORTH VALLEY
# 111641        50769                HOAG ORTHOPEDIC INSTITUTE
#
#          Provider Street Address Provider City Provider State  \
# 111406        27200 CALAROGA AVE       HAYWARD             CA
# 111407           2700 DOLBEER ST        EUREKA             CA
# 111408      1501 TROUSDALE DRIVE    BURLINGAME             CA
# 111409           1000 TRANCAS ST          NAPA             CA
# 111410          10 WOODLAND ROAD  SAINT HELENA             CA
# ...                          ...           ...            ...
# 111637      4501 SAND CREEK ROAD       ANTIOCH             CA
# 111638        18321 CLARK STREET       TARZANA             CA
# 111639             1100 BUTTE ST       REDDING             CA
# 111640           455 PLUMAS BLVD     YUBA CITY             CA
# 111641  16250 SAND CANYON AVENUE        IRVINE             CA
#
#         Provider Zip Code Hospital Referral Region Description  \
# 111406              94545                  CA - Alameda County
# 111407              95501                         CA - Redding
# 111408              94010                CA - San Mateo County
# 111409              94558                            CA - Napa
# 111410              94574                            CA - Napa
# ...                   ...                                  ...
# 111637              94531             CA - Contra Costa County
# 111638              91356                     CA - Los Angeles
# 111639              96001                         CA - Redding
# 111640              95991                      CA - Sacramento
# 111641              92618                   CA - Orange County
#
#         Count_Discharges   Average Covered Charges   Total_Cost  \
# 111406                38                  131073.52    23114.21
# 111407               116                   75480.05    17263.56
# 111408               146                   89325.10    17128.93
# 111409               147                  101016.42    17684.37
# 111410               632                  112724.85    19995.29
# ...                  ...                        ...         ...
# 111637                22                   43627.54    15823.04
# 111638                51                  121987.56    14946.50
# 111639               134                  158240.23    16191.52
# 111640               158                   67368.07    13102.56
# 111641               878                   52065.64    13136.21
#
#         Average Medicare Payments DRG_Code  \
# 111406                   21993.15      470
# 111407                   15037.61      470
# 111408                   14633.80      470
# 111409                   15969.88      470
# 111410                   17583.88      470
# ...                           ...      ...
# 111637                   14701.22      470
# 111638                   13456.66      470
# 111639                   15125.10      470
# 111640                   11397.58      470
# 111641                   10805.58      470
#
#                                           DRG_Description  Avg_DRG_Cost  \
# 111406  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111407  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111408  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111409  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111410  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# ...                                                   ...           ...
# 111637  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111638  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111639  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111640  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
# 111641  MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOW...  14566.929215
#
#           Cost_Diff
# 111406  8547.280785
# 111407  2696.630785
# 111408  2562.000785
# 111409  3117.440785
# 111410  5428.360785
# ...             ...
# 111637  1256.110785
# 111638   379.570785
# 111639  1624.590785
# 111640 -1464.369215
# 111641 -1430.719215
#
# [235 rows x 15 columns]

# %% [markdown]
# ### 2b) (Translation to R, see .Rmd)
# Translate the provided code from Python to R, improving it if neccessary to best addresses the question:
# **Which hospitals in California cost the most/least?**.
#
# Provide your insights from the output of the code.

# %% [markdown]
# ## Task 3: What is the relationship between cost and quality?
# Is it true that "you get what you pay for" when it comes to hospital care? Now that we have completed some preliminary analyses of the cost and quality of Hospitals in the state of California, we would like to take a look at their relationship jointly. That is, we would like to see how cost relates to quality by combining the output from the first two questions.
#
# With the language of your choosing (either R or Python),
#
# ### 3a) Join/Merge together Cost and Quality tables
# Join together the resulting tables from tasks 1 and 2. What type of join did you perform and why? How many hospitals were removed (if any) due to the type of join?
#
#
# ### 3b) Create a visualization that addresses this question
# Using the insights you gained from the Tasks 1 and 2 above, create a visualization to address the question. Provide a detailed explanation of the insights gained from your visualization.
#
#
# ### 3c) Extend the insights from above
# With the code and data you used in the previous tasks as a base, provide additional insights that augment those from the previous task (3b).
#
# For example, you could consider:
# - Visualizing more variables from the datasets in tasks 1 and 2
# - Leveraging the whole dataset to understand where the California providers stand nationally
# - Gather outside data (e.g. Census) and join with the data in this task (e.g. using Zip Code)
# - Create an interactive plot (plotly or ggplotly) to help explore an expanded dataset
#
#
# Be sure to structure this response as:
#
#     1) Question or hypothesis
#     2) Code/Data Formatting and Plotting
#     3) Description of new insights
